# %%
import pandas as pd
import numpy as np

# %%
data_frame=pd.read_csv(r"C:\Users\ahmed\Revision\workshop\lesson_plans\Lesson_Plans\dataset\cleaned_data\Cleaned_outlier.csv")
data_frame
# Out:
#      Unnamed: 0  Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood  \
# 0             0       5.0        3.0     1998.685661  Expensive Area
# 1             1       5.0        2.0     1744.694280  Expensive Area
# 2             2       5.0        3.0     1814.016403        Low-Cost
# 3             3       6.0        4.0     2409.211943        Low-Cost
# 4             5       3.0        2.0     1706.345217    Middle Class
# ..          ...       ...        ...             ...             ...
# 378         395       4.0        3.0     2295.126525  Expensive Area
# 379         397       4.0        2.0     1845.406938    Middle Class
# 380         398       4.0        2.0     1376.915628  Expensive Area
# 381         399       5.0        3.0     2028.356204    Middle Class
# 382         400       3.0        2.0     1668.935141    Middle Class
#
#     Condition         Price  New column
# 0        Fair  1.223983e+06         1.0
# 1        Poor  1.125837e+06         2.0
# 2        Good  1.078208e+06         3.0
# 3        Poor  1.240305e+06         4.0
# 4        Poor  9.781016e+05         6.0
# ..        ...           ...         ...
# 378      Good  1.360911e+06       400.0
# 379      Fair  1.002568e+06       402.0
# 380      Poor  1.004517e+06       403.0
# 381      Fair  1.066774e+06       404.0
# 382      Poor  9.122537e+05       405.0
#
# [383 rows x 8 columns]

# %%
# remove_unwanted=data_frame.drop("Unnamed: 0",axis=1)
remove_unwanted=data_frame.drop(["Unnamed: 0","New column"],axis=1)
remove_unwanted
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood Condition  \
# 0         5.0        3.0     1998.685661  Expensive Area      Fair
# 1         5.0        2.0     1744.694280  Expensive Area      Poor
# 2         5.0        3.0     1814.016403        Low-Cost      Good
# 3         6.0        4.0     2409.211943        Low-Cost      Poor
# 4         3.0        2.0     1706.345217    Middle Class      Poor
# ..        ...        ...             ...             ...       ...
# 378       4.0        3.0     2295.126525  Expensive Area      Good
# 379       4.0        2.0     1845.406938    Middle Class      Fair
# 380       4.0        2.0     1376.915628  Expensive Area      Poor
# 381       5.0        3.0     2028.356204    Middle Class      Fair
# 382       3.0        2.0     1668.935141    Middle Class      Poor
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %%
df=remove_unwanted.copy()
df
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood Condition  \
# 0         5.0        3.0     1998.685661  Expensive Area      Fair
# 1         5.0        2.0     1744.694280  Expensive Area      Poor
# 2         5.0        3.0     1814.016403        Low-Cost      Good
# 3         6.0        4.0     2409.211943        Low-Cost      Poor
# 4         3.0        2.0     1706.345217    Middle Class      Poor
# ..        ...        ...             ...             ...       ...
# 378       4.0        3.0     2295.126525  Expensive Area      Good
# 379       4.0        2.0     1845.406938    Middle Class      Fair
# 380       4.0        2.0     1376.915628  Expensive Area      Poor
# 381       5.0        3.0     2028.356204    Middle Class      Fair
# 382       3.0        2.0     1668.935141    Middle Class      Poor
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %%
print(df['Neighborhood'].value_counts())
# Out:
# Neighborhood
# Middle Class      154
# Expensive Area    116
# Low-Cost          113
# Name: count, dtype: int64

# %%
# df['Bathrooms']=df['Bathrooms'].astype(int)
df['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 2.0    195
# 3.0    115
# 1.0     54
# 4.0     19
# Name: count, dtype: int64

# %%
df['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 4.0    158
# 3.0    113
# 5.0     51
# 2.0     40
# 6.0     13
# 1.0      8
# Name: count, dtype: int64

# %%
df["Bedrooms"] = df["Bedrooms"].round().astype("Int64")
df["Bathrooms"] = df["Bathrooms"].round().astype("Int64")
df["HouseSize_sqft"] = df["HouseSize_sqft"].round().astype("int64")
df
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood Condition  \
# 0           5          3            1999  Expensive Area      Fair
# 1           5          2            1745  Expensive Area      Poor
# 2           5          3            1814        Low-Cost      Good
# 3           6          4            2409        Low-Cost      Poor
# 4           3          2            1706    Middle Class      Poor
# ..        ...        ...             ...             ...       ...
# 378         4          3            2295  Expensive Area      Good
# 379         4          2            1845    Middle Class      Fair
# 380         4          2            1377  Expensive Area      Poor
# 381         5          3            2028    Middle Class      Fair
# 382         3          2            1669    Middle Class      Poor
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %%
df['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 4    158
# 3    113
# 5     51
# 2     40
# 6     13
# 1      8
# Name: count, dtype: Int64

# %%
test=pd.read_csv(r"C:\Users\ahmed\Revision\workshop\lesson_plans\Lesson_Plans\dataset\house_Dataset.csv")
test
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood  Condition  \
# 0         4.0        3.0     1391.375680        Low-Cost       Fair
# 1         5.0        1.0     2052.464880  Expensive Area       Fair
# 2         3.0        2.0     1461.398985    Middle Class       Fair
# 3         NaN        NaN     2553.186672    Middle Class       Fair
# 4         5.0        1.0     1819.666201        Low-Cost       Good
# ..        ...        ...             ...             ...        ...
# 400       1.0        2.0     1817.883763    Middle Class       Good
# 401       3.0        1.0     1493.665076  Expensive Area  Excellent
# 402       1.0        3.0     2785.979703    Middle Class       Poor
# 403       3.0        1.0     1879.180496    Middle Class       Fair
# 404       4.0        2.0      896.594390        Low-Cost  Excellent
#
#             Price
# 0    3.893567e+09
# 1    2.372000e+06
# 2    3.560000e+05
# 3    5.372000e+05
# 4    4.430000e+05
# ..            ...
# 400  3.530000e+05
# 401  3.071000e+05
# 402  4.862000e+05
# 403  4.121000e+05
# 404  2.702000e+05
#
# [405 rows x 6 columns]

# %%
test["Neighborhood"].value_counts()
# Out:
# Neighborhood
# Expensive Area     104
# Middle Class        98
# Outskirts           95
# Low-Cost            84
#  Low-Cost            2
#  Expensive Area      1
#  Outskirts           1
# Name: count, dtype: int64

# %%
test["Neighborhood"] = test["Neighborhood"].astype(str).str.strip()
test["Condition"] = test["Condition"].astype(str).str.strip()

# %%
test["Neighborhood"].value_counts()
# Out:
# Neighborhood
# Expensive Area    105
# Middle Class       98
# Outskirts          96
# Low-Cost           86
# nan                20
# Name: count, dtype: int64

# %%
# df["Neighborhood"] = df["Neighborhood"].astype(str).str.strip()
# df["Neighborhood"].value_counts()

# %% [markdown]
# ### Numeric and Categorical

# %%
no_cols=df.select_dtypes(["number"]).columns.difference(["Price"]).tolist()
# no_cols=['Bathrooms', 'Bedrooms', 'Condition', 'HouseSize_sqft', 'Neighborhood']
cat_cols = df.select_dtypes(exclude="number").columns
no_cols
# Out:
# ['Bathrooms', 'Bedrooms', 'HouseSize_sqft']

# %% [markdown]
# ### Standardization (StandardScaler)
# Transform mean = 0, std = 1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
scaler=StandardScaler()
transformed_data=scaler.fit_transform(df[no_cols])
transformed_data
# scaled_df = pd.DataFrame(transformed_data, columns=no_cols,index=df.index)
# scaled_df
# final_df = pd.concat([scaled_df, df[cat_cols]], axis=1)
# Out:
# array([[ 0.97969484,  1.3415373 ,  0.5464702 ],
#        [-0.34151334,  1.3415373 , -0.15444632],
#        [ 0.97969484,  1.3415373 ,  0.03596014],
#        ...,
#        [-0.34151334,  0.35911132, -1.16994741],
#        [ 0.97969484,  1.3415373 ,  0.6264961 ],
#        [-0.34151334, -0.62331466, -0.36416937]])

# %%
scaled_df = pd.DataFrame(transformed_data, columns=no_cols,index=df.index)
final_df = pd.concat([scaled_df, df[cat_cols]], axis=1)
final_df
# Out:
#      Bathrooms  Bedrooms  HouseSize_sqft    Neighborhood Condition
# 0     0.979695  1.341537        0.546470  Expensive Area      Fair
# 1    -0.341513  1.341537       -0.154446  Expensive Area      Poor
# 2     0.979695  1.341537        0.035960        Low-Cost      Good
# 3     2.300903  2.323963        1.677871        Low-Cost      Poor
# 4    -0.341513 -0.623315       -0.262067    Middle Class      Poor
# ..         ...       ...             ...             ...       ...
# 378   0.979695  0.359111        1.363286  Expensive Area      Good
# 379  -0.341513  0.359111        0.121505    Middle Class      Fair
# 380  -0.341513  0.359111       -1.169947  Expensive Area      Poor
# 381   0.979695  1.341537        0.626496    Middle Class      Fair
# 382  -0.341513 -0.623315       -0.364169    Middle Class      Poor
#
# [383 rows x 5 columns]

# %%
df[no_cols]=transformed_data
df[no_cols]
# Out:
#      Bathrooms  Bedrooms  HouseSize_sqft
# 0     0.979695  1.341537        0.546470
# 1    -0.341513  1.341537       -0.154446
# 2     0.979695  1.341537        0.035960
# 3     2.300903  2.323963        1.677871
# 4    -0.341513 -0.623315       -0.262067
# ..         ...       ...             ...
# 378   0.979695  0.359111        1.363286
# 379  -0.341513  0.359111        0.121505
# 380  -0.341513  0.359111       -1.169947
# 381   0.979695  1.341537        0.626496
# 382  -0.341513 -0.623315       -0.364169
#
# [383 rows x 3 columns]

# %% [markdown]
# ### Normalization (MinMaxScaler)

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df["column_Name"] = scaler.fit_transform(df[["column_Name"]])

# %%
df
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft    Neighborhood Condition  \
# 0    1.341537   0.979695        0.546470  Expensive Area      Fair
# 1    1.341537  -0.341513       -0.154446  Expensive Area      Poor
# 2    1.341537   0.979695        0.035960        Low-Cost      Good
# 3    2.323963   2.300903        1.677871        Low-Cost      Poor
# 4   -0.623315  -0.341513       -0.262067    Middle Class      Poor
# ..        ...        ...             ...             ...       ...
# 378  0.359111   0.979695        1.363286  Expensive Area      Good
# 379  0.359111  -0.341513        0.121505    Middle Class      Fair
# 380  0.359111  -0.341513       -1.169947  Expensive Area      Poor
# 381  1.341537   0.979695        0.626496    Middle Class      Fair
# 382 -0.623315  -0.341513       -0.364169    Middle Class      Poor
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %% [markdown]
# ### ENCODING CATEGORICAL VARIABLES

# %%
df["Condition"].value_counts()
# Out:
# Condition
# Poor    151
# Fair    124
# Good    108
# Name: count, dtype: int64

# %% [markdown]
# ### 1- Manual Encoding Mapping

# %%
# Clean strings
df["Neighborhood"] = df["Neighborhood"].astype(str).str.strip()
df["Condition"] = df["Condition"].astype(str).str.strip()

# Manual mapping dictionaries
neighborhood_map = {
    "Low-Cost": 0,
    "Outskirts": 1,
    "Middle Class": 2,
    "Expensive Area": 3
}

condition_map = {
    "Poor": 0,
    "Fair": 1,
    "Good": 2,
    "Excellent": 3
}

# Apply mapping
df["Neighborhood"] = df["Neighborhood"].map(neighborhood_map)
df["Condition"] = df["Condition"].map(condition_map)

# %% [markdown]
# ### 2-OrdinalEncoder

# %% [markdown]
# ### 3 LabelEncoder-- (No order)gives automatic numbering- alphabetical order
# Use LabelEncoder only if:
#
# Data has no ordinal meaning
#
# You are using tree-based models: RandomForest, DecisionTree, XGBoost
# (they don't care about numeric order

# %%
from sklearn.preprocessing import LabelEncoder

data = ['Red', 'Green', 'Blue', 'Red']

le = LabelEncoder()
encoded_data = le.fit_transform(data)
print(f"Encoded Data: {encoded_data}")
# Out:
# Encoded Data: [2 1 0 2]

# %%
# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# df["Condition"] = le.fit_transform(df["Condition"])

# %% [markdown]
# ## 4: OneHotEncoder

# %%
df
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft  Neighborhood  Condition  \
# 0    1.341537   0.979695        0.546470             3          1
# 1    1.341537  -0.341513       -0.154446             3          0
# 2    1.341537   0.979695        0.035960             0          2
# 3    2.323963   2.300903        1.677871             0          0
# 4   -0.623315  -0.341513       -0.262067             2          0
# ..        ...        ...             ...           ...        ...
# 378  0.359111   0.979695        1.363286             3          2
# 379  0.359111  -0.341513        0.121505             2          1
# 380  0.359111  -0.341513       -1.169947             3          0
# 381  1.341537   0.979695        0.626496             2          1
# 382 -0.623315  -0.341513       -0.364169             2          0
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %% [markdown]
# ### Feature Slection

# %% [markdown]
# ### which features influence the target variable.
# ### how important is a feature

# %%
feature_Selection=df.copy()
feature_Selection
# Out:
#      Bedrooms  Bathrooms  HouseSize_sqft  Neighborhood  Condition  \
# 0    1.341537   0.979695        0.546470             3          1
# 1    1.341537  -0.341513       -0.154446             3          0
# 2    1.341537   0.979695        0.035960             0          2
# 3    2.323963   2.300903        1.677871             0          0
# 4   -0.623315  -0.341513       -0.262067             2          0
# ..        ...        ...             ...           ...        ...
# 378  0.359111   0.979695        1.363286             3          2
# 379  0.359111  -0.341513        0.121505             2          1
# 380  0.359111  -0.341513       -1.169947             3          0
# 381  1.341537   0.979695        0.626496             2          1
# 382 -0.623315  -0.341513       -0.364169             2          0
#
#             Price
# 0    1.223983e+06
# 1    1.125837e+06
# 2    1.078208e+06
# 3    1.240305e+06
# 4    9.781016e+05
# ..            ...
# 378  1.360911e+06
# 379  1.002568e+06
# 380  1.004517e+06
# 381  1.066774e+06
# 382  9.122537e+05
#
# [383 rows x 6 columns]

# %% [markdown]
# ### using correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlations with the target
# numeric_cols=feature_Selection.select_dtype('number')

corr = feature_Selection.corr()

# Plot heatmap
plt.figure(figsize=(5, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Feature Correlation with Target (Price)')
plt.show()

# %%
corr
# Out:
#                 Bedrooms  Bathrooms  HouseSize_sqft  Neighborhood  Condition  \
# Bedrooms        1.000000   0.353094        0.666009     -0.071979  -0.014856
# Bathrooms       0.353094   1.000000        0.546713     -0.057035  -0.037625
# HouseSize_sqft  0.666009   0.546713        1.000000     -0.031576  -0.006902
# Neighborhood   -0.071979  -0.057035       -0.031576      1.000000  -0.109277
# Condition      -0.014856  -0.037625       -0.006902     -0.109277   1.000000
# Price           0.648271   0.556977        0.881823      0.225401   0.004080
#
#                    Price
# Bedrooms        0.648271
# Bathrooms       0.556977
# HouseSize_sqft  0.881823
# Neighborhood    0.225401
# Condition       0.004080
# Price           1.000000

# %%
import joblib

# Save the scaler
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
joblib.dump(no_cols, "scaled_columns.pkl")
# Out:
# ['scaled_columns.pkl']
